# %% [markdown]
# # MaxLab Notebook Assistant
#
# This notebook initializes a Semantic Kernel-powered assistant that can analyze notebook code,
# suggest improvements, and provide financial insights.
#
# **Prerequisites**:
# - Run `setup.ps1` to install dependencies
# - For Azure OpenAI, set `AZURE_OPENAI_ENDPOINT`, `AZURE_OPENAI_API_KEY`, `AZURE_OPENAI_DEPLOYMENT_NAME`

# %%
# %load_ext maxlab
# Out:
# **MaxLab Ready! 🤖**
#
# 🔷 **Azure OpenAI** configured
# - Deployment: `gpt-4.1-mini`
# - Endpoint: `https://maxlabai-resource.openai.azure.com/`
# - API Version: `2024-05-01-preview`
#
# Available plugins: `notebook_analyzer`, `finance`
#
# Usage:
# ```python
# # Simple usage - auto-displays as markdown:
# response = await agent.chat('Your question here')
# response
#
# # Or explicitly display:
# display(Markdown(response))
# ```

# %% [markdown]
# ## Single-Turn Chat
# Ask the assistant to analyze a snippet or give suggestions.

# %%
# Example: Ask for notebook improvement ideas
prompt = (
    "Can you tell me the difference between Poisson and Exponential distributions?"
)

# Get markdown response (default)
response = await agent.chat(prompt)
response
# Out:
# 'Certainly! The Poisson and Exponential distributions are both related to events occurring randomly over time or space, but they describe different aspects and have distinct characteristics:\n\n1. Poisson Distribution:\n- Describes the probability of a given number of events happening in a fixed interval of time or space.\n- It is a discrete distribution.\n- It is defined by the parameter λ (lambda), which is the average rate of events per interval.\n- Commonly used to model the count of occurrences, such as the number of phone calls received by a call center in an hour.\n- The probability mass function (PMF) for Poisson is P(X=k) = (λ^k * e^(-λ)) / k!, where k is the number of events.\n\n2. Exponential Distribution:\n- Describes the time between consecutive events in a Poisson process.\n- It is a continuous distribution.\n- It is also parameterized by λ, the rate parameter, which is the reciprocal of the mean time between events.\n- Often used to model waiting times or durations, such as the time between arrivals of buses at a stop.\n- The probability density function (PDF) for Exponential is f(t) = λ * e^(-λt) for t ≥ 0.\n\nIn summary:\n- The Poisson distribution quantifies how many events occur in a set interval.\n- The Exponential distribution measures the waiting time between those events.\n\nThey are mathematically linked because the Exponential distribution models the inter-arrival times of a Poisson process.'
