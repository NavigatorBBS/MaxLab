# %% [markdown]
# # MaxLab Notebook Assistant
#
# This notebook initializes a Semantic Kernel-powered assistant that can analyze notebook code,
# suggest improvements, and provide financial insights.
#
# **Prerequisites**:
# - Run `setup.ps1` to install dependencies
# - For OpenAI, set `OPENAI_API_KEY` in your `.env` file
# - Optionally set `OPENAI_CHAT_MODEL_ID` (defaults to gpt-4o)

# %%
# %load_ext maxlab
# Out:
# ❌ **MaxLab Extension Error**
#
# ```
# The OpenAI API key is required.
# ```

# %% [markdown]
# ## Single-Turn Chat
# Ask the assistant to analyze a snippet or give suggestions.

# %%
# Example: Ask for analysis
prompt = (
    "Can you tell me the difference between Supervised and Unsupervised machine learning?"
)

# Get markdown response (default)
response = await agent.chat(prompt)
response
# Out:
# 'Certainly! Supervised and unsupervised machine learning are two primary types of machine learning algorithms, each suited for different types of tasks.\n\n### Supervised Learning\n- **Definition**: Supervised learning involves training a model on a labeled dataset, meaning that each training example is paired with an output label. The goal is for the model to learn to predict the output labels for new, unseen data.\n- **Examples**: Common tasks include classification (e.g., spam detection in emails, image recognition) and regression (e.g., predicting house prices).\n- **Process**: The algorithm learns from the training data by minimizing the error in predictions through techniques like backpropagation (in neural networks) or minimizing a loss function.\n- **Datasets**: Requires a labeled dataset, where the true outcome is known.\n\n### Unsupervised Learning\n- **Definition**: Unsupervised learning deals with datasets that do not have labeled responses. The goal is to infer the natural structure present within a set of data points.\n- **Examples**: Common tasks include clustering (e.g., customer segmentation), association (e.g., market basket analysis), and dimensionality reduction (e.g., Principal Component Analysis).\n- **Process**: The algorithm tries to learn the patterns and the structure from the input data without references to known or labeled outcomes.\n- **Datasets**: Works with unlabeled data where the model identifies patterns based solely on the structure of the data itself.\n\n### Key Differences:\n- **Objective**: Supervised learning aims to predict an output given an input, while unsupervised learning aims to find patterns or intrinsic structures in input data.\n- **Data Requirement**: Supervised learning requires labeled data, whereas unsupervised learning does not.\n- **Outcome**: The outcome in supervised learning is the correct label or value, whereas, in unsupervised learning, it is typically a more abstract form of knowledge (e.g., input data grouping).\n\nIn summary, if you have a labeled dataset and want to predict outcomes based on that, you would use supervised learning. If you want to explore your data and uncover hidden patterns, you would use unsupervised learning.'
