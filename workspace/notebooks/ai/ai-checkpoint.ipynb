# %% [markdown]
# # MaxLab Copilot Server Test
#
# This notebook sends a test message to the local MaxLab Copilot server extension and prints the reply.

# %%
# Ensure the workspace src package is on sys.path if running outside installed envs
import sys
sys.path.insert(0, r"C:\Users\chris\code\MaxLab\workspace\src")

from maxlab.copilot_server.magics import copilot_chat
print('Sending message to Copilot server...')
reply = copilot_chat('Hello from notebook')
print('Reply:', reply)
