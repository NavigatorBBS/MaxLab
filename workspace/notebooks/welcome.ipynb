# %% [markdown]
# # 👋 Welcome to MaxLab
#
# This notebook is your starting point inside the MaxLab environment, built by **NavigatorBBS**.
#
# MaxLab is a modular, restart-safe JupyterLab stack designed for clarity, reproducibility, and long-term maintainability. Whether you're exploring data, prototyping systems, or documenting workflows — you're in the right place.

# %% [markdown]
# ## 🧱 Environment Details
#
# - **Kernel**: MaxLab Kernel
# - **Python version**: 3.12
# - **Conda environment**: `MAXLAB/`
# - **Port**: 8888 (served locally)

# %%
import sys
print("Python version:", sys.version)
# Out:
# Python version: 3.12.12 | packaged by conda-forge | (main, Jan 26 2026, 23:38:32) [MSC v.1944 64 bit (AMD64)]

# %%
# !pip list --format=columns
# Out:
# Package                            Version     Editable project location
# ---------------------------------- ----------- --------------------------
# aiohappyeyeballs                   2.6.1
# aiohttp                            3.13.3
# aioice                             0.10.2
# aiortc                             1.14.0
# aiosignal                          1.4.0
# anaconda-anon-usage                0.7.5
# anaconda-auth                      0.12.3
# anaconda-cli-base                  0.7.0
# annotated-types                    0.6.0
# anyio                              4.12.1
# archspec                           0.2.5
# argon2-cffi                        25.1.0
# argon2-cffi-bindings               25.1.0
# arrow                              1.4.0
# asttokens                          3.0.1
# async-lru                          2.1.0
# attrs                              25.4.0
# av                                 16.1.0
# azure-ai-agents                    1.2.0b6
# ...

# %% [markdown]
# ## 🚀 Next Steps
#
# - Create a new notebook in the `workspace/` folder
# - Explore the `requirements.txt` to see available packages
# - Use `start.sh` to launch JupyterLab safely
# - Modify `.env` to customize your domain, email, or port
